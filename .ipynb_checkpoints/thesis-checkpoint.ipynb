# %%
# !pip install gensim
# !pip install nltk
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.9/site-packages (4.1.2)
# Requirement already satisfied: scipy>=0.18.1 in /opt/conda/lib/python3.9/site-packages (from gensim) (1.6.3)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from gensim) (1.20.3)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.9/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.9/site-packages (from nltk) (2021.11.10)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from nltk) (4.60.0)

# %%
import pandas as pd
import numpy as np

dataset = pd.read_csv('./dataset/jiradataset_issues_v1.4.csv', encoding='utf-8')

# %%
dataset.head()
# Out:
#   assignee.name                                         components  \
# 0           NaN  [{u'id': u'12786', u'self': u'https://jira.spr...
# 1           NaN  [{u'id': u'12784', u'self': u'https://jira.spr...
# 2      jvalkeal                                                 []
# 3           NaN                                                 []
# 4           NaN                                                 []
#
#                         created    creator.name  \
# 0  2016-03-31T22:35:55.000+0000  thomas.risberg
# 1  2016-03-14T18:09:51.000+0000      manju4ever
# 2  2016-03-03T13:22:14.000+0000        jvalkeal
# 3  2016-02-29T10:00:18.000+0000        aliiqbal
# 4  2016-02-26T15:57:18.000+0000        grussell
#
#                                          description fixVersions  \
# 0  The MapReduce samples should have "yarn.resour...          []
# 1  When i use the admin-ui web portal which runs ...          []
# 2  In a case where reactor's ringbuffer is full a...          []
# 3  if we put a custom module static properties in...          []
# 4  Custom conversion is broken.\r\r\n\r\r\nIf the...          []
#
#   issuetype.name  issuetype.subtask priority.name   reporter.name  ...  \
# 0    Improvement              False         Minor  thomas.risberg  ...
# 1            Bug              False       Trivial      manju4ever  ...
# 2            Bug              False         Major        jvalkeal  ...
# 3            Bug              False         Major        aliiqbal  ...
# 4            Bug              False         Major        grussell  ...
#
#   status.name status.statusCategory.name  \
# 0       To Do                      To Do
# 1       To Do                      To Do
# 2       In PR                In Progress
# 3       To Do                      To Do
# 4       To Do                      To Do
#
#                                              summary  \
# 0  Add "yarn.resourcemanager.scheduler.address" t...
# 1  Admin UI login Page failing to load due to req...
# 2          gpfdist may fail to shutdown with backlog
# 3  Cant completely remove custom module after put...
# 4  Provisioning of Custom input/output Converters...
#
#                         updated  \
# 0  2016-03-31T22:35:55.000+0000
# 1  2016-03-14T18:09:51.000+0000
# 2  2016-03-03T18:41:19.000+0000
# 3  2016-03-13T10:24:15.000+0000
# 4  2016-02-26T16:08:03.000+0000
#
#                                             versions watches.watchCount  \
# 0                                                 []                  1
# 1  [{u'archived': False, u'description': u'1.3.0 ...                  1
# 2  [{u'archived': False, u'name': u'1.3.1', u'sel...                  1
# 3  [{u'archived': False, u'name': u'1.2.1', u'sel...                  1
# 4                                                 []                  1
#
#        key storypoints project  sprint
# 0  XD-3753         2.0      xd     NaN
# 1  XD-3752        20.0      xd     NaN
# 2  XD-3751         5.0      xd     NaN
# 3  XD-3750         1.0      xd     NaN
# 4  XD-3749         5.0      xd     NaN
#
# [5 rows x 24 columns]

# %%
dataset.describe()
# Out:
#            status.id  watches.watchCount   storypoints
# count  111048.000000       111048.000000  2.484000e+04
# mean      961.120479            2.452867  1.080227e+03
# std      2944.655296            3.641834  1.694728e+05
# min         1.000000            0.000000  0.000000e+00
# 25%         6.000000            1.000000  2.000000e+00
# 50%         6.000000            2.000000  3.000000e+00
# 75%         6.000000            3.000000  5.000000e+00
# max     10953.000000          156.000000  2.671011e+07

# %% [markdown]
# Include only xd project

# %%
dataset.loc[dataset["project"] == "xd"]
dataset.describe()
# Out:
#            status.id  watches.watchCount   storypoints
# count  111048.000000       111048.000000  2.484000e+04
# mean      961.120479            2.452867  1.080227e+03
# std      2944.655296            3.641834  1.694728e+05
# min         1.000000            0.000000  0.000000e+00
# 25%         6.000000            1.000000  2.000000e+00
# 50%         6.000000            2.000000  3.000000e+00
# 75%         6.000000            3.000000  5.000000e+00
# max     10953.000000          156.000000  2.671011e+07

# %% [markdown]
# ## Data prep

# %% [markdown]
# Merge description and summary into one column - text

# %%
dataset['description'] = dataset['description'].fillna("")
dataset['summary'] = dataset['summary'].fillna("")

dataset["text"] = dataset["description"] + " " + dataset["summary"]
dataset.columns.values
# Out:
# array(['assignee.name', 'components', 'created', 'creator.name',
#        'description', 'fixVersions', 'issuetype.name',
#        'issuetype.subtask', 'priority.name', 'reporter.name',
#        'resolution.description', 'resolution.name', 'resolutiondate',
#        'status.id', 'status.name', 'status.statusCategory.name',
#        'summary', 'updated', 'versions', 'watches.watchCount', 'key',
#        'storypoints', 'project', 'sprint', 'text'], dtype=object)

# %% [markdown]
# Map priorities to numerical values

# %%
import helpers.prioritymapper as pm

dataset["priority"]= dataset.apply(lambda x: pm.mapPriority(x["project"], x["priority.name"]), axis=1)
dataset.head()
# Out:
#   assignee.name                                         components  \
# 0           NaN  [{u'id': u'12786', u'self': u'https://jira.spr...
# 1           NaN  [{u'id': u'12784', u'self': u'https://jira.spr...
# 2      jvalkeal                                                 []
# 3           NaN                                                 []
# 4           NaN                                                 []
#
#                         created    creator.name  \
# 0  2016-03-31T22:35:55.000+0000  thomas.risberg
# 1  2016-03-14T18:09:51.000+0000      manju4ever
# 2  2016-03-03T13:22:14.000+0000        jvalkeal
# 3  2016-02-29T10:00:18.000+0000        aliiqbal
# 4  2016-02-26T15:57:18.000+0000        grussell
#
#                                          description fixVersions  \
# 0  The MapReduce samples should have "yarn.resour...          []
# 1  When i use the admin-ui web portal which runs ...          []
# 2  In a case where reactor's ringbuffer is full a...          []
# 3  if we put a custom module static properties in...          []
# 4  Custom conversion is broken.\r\r\n\r\r\nIf the...          []
#
#   issuetype.name  issuetype.subtask priority.name   reporter.name  ...  \
# 0    Improvement              False         Minor  thomas.risberg  ...
# 1            Bug              False       Trivial      manju4ever  ...
# 2            Bug              False         Major        jvalkeal  ...
# 3            Bug              False         Major        aliiqbal  ...
# 4            Bug              False         Major        grussell  ...
#
#                                              summary  \
# 0  Add "yarn.resourcemanager.scheduler.address" t...
# 1  Admin UI login Page failing to load due to req...
# 2          gpfdist may fail to shutdown with backlog
# 3  Cant completely remove custom module after put...
# 4  Provisioning of Custom input/output Converters...
#
#                         updated  \
# 0  2016-03-31T22:35:55.000+0000
# 1  2016-03-14T18:09:51.000+0000
# 2  2016-03-03T18:41:19.000+0000
# 3  2016-03-13T10:24:15.000+0000
# 4  2016-02-26T16:08:03.000+0000
#
#                                             versions  watches.watchCount  \
# 0                                                 []                   1
# 1  [{u'archived': False, u'description': u'1.3.0 ...                   1
# 2  [{u'archived': False, u'name': u'1.3.1', u'sel...                   1
# 3  [{u'archived': False, u'name': u'1.2.1', u'sel...                   1
# 4                                                 []                   1
#
#        key storypoints project sprint  \
# 0  XD-3753         2.0      xd    NaN
# 1  XD-3752        20.0      xd    NaN
# 2  XD-3751         5.0      xd    NaN
# 3  XD-3750         1.0      xd    NaN
# 4  XD-3749         5.0      xd    NaN
#
#                                                 text  priority
# 0  The MapReduce samples should have "yarn.resour...         2
# 1  When i use the admin-ui web portal which runs ...         1
# 2  In a case where reactor's ringbuffer is full a...         3
# 3  if we put a custom module static properties in...         3
# 4  Custom conversion is broken.\r\r\n\r\r\nIf the...         3
#
# [5 rows x 26 columns]

# %% [markdown]
# Add 1 story point for issues that don't have storypoints defined

# %%
dataset['storypoints'] = dataset['storypoints'].fillna(1)

# %% [markdown]
# Leave only necessary columns into the dataframe

# %%
dataset = dataset[["created", "assignee.name", "priority", "status.name", "text", "storypoints", "project", "resolution.name", "description", "summary"]]

# %% [markdown]
# Define backlog

# %%
backlog = dataset.loc[(dataset["assignee.name"].isna()) & (dataset["resolution.name"].isna()) & (dataset["status.name"] == "To Do")]
backlog.head()
# Out:
#                         created assignee.name  priority status.name  \
# 0  2016-03-31T22:35:55.000+0000           NaN         2       To Do
# 1  2016-03-14T18:09:51.000+0000           NaN         1       To Do
# 3  2016-02-29T10:00:18.000+0000           NaN         3       To Do
# 4  2016-02-26T15:57:18.000+0000           NaN         3       To Do
# 6  2016-02-23T18:31:37.000+0000           NaN         2       To Do
#
#                                                 text  storypoints project  \
# 0  The MapReduce samples should have "yarn.resour...          2.0      xd
# 1  When i use the admin-ui web portal which runs ...         20.0      xd
# 3  if we put a custom module static properties in...          1.0      xd
# 4  Custom conversion is broken.\r\r\n\r\r\nIf the...          5.0      xd
# 6  http://stackoverflow.com/questions/35563064/pr...          1.0      xd
#
#   resolution.name                                        description  \
# 0             NaN  The MapReduce samples should have "yarn.resour...
# 1             NaN  When i use the admin-ui web portal which runs ...
# 3             NaN  if we put a custom module static properties in...
# 4             NaN  Custom conversion is broken.\r\r\n\r\r\nIf the...
# 6             NaN  http://stackoverflow.com/questions/35563064/pr...
#
#                                              summary
# 0  Add "yarn.resourcemanager.scheduler.address" t...
# 1  Admin UI login Page failing to load due to req...
# 3  Cant completely remove custom module after put...
# 4  Provisioning of Custom input/output Converters...
# 6  Rabbit Bus: Expose ChannelCacheSize on Caching...

# %% [markdown]
# Define done issues

# %%
df = dataset.loc[(dataset["assignee.name"].notna()) & (dataset["resolution.name"] =="Complete") & (dataset["status.name"] == "Done")]
df.head()
# Out:
#                          created assignee.name  priority status.name  \
# 7   2016-02-23T18:18:48.000+0000      grussell         2        Done
# 8   2016-02-23T18:04:09.000+0000      grussell         2        Done
# 9   2016-02-22T15:27:31.000+0000      grussell         2        Done
# 10  2016-02-17T14:28:31.000+0000        abilan         2        Done
# 11  2016-02-16T14:59:06.000+0000     dturanski         2        Done
#
#                                                  text  storypoints project  \
# 7                    Update Spring Framework to 4.2.4          1.0      xd
# 8   Update to amqp-client 3.6.0 and spring-amqp 1....          1.0      xd
# 9   Related to XD-2567 which fixed this problem, b...          1.0      xd
# 10  See INT-3956 Update to Spring Integration 4.2....          1.0      xd
# 11  The following XD components have been identifi...          3.0      xd
#
#    resolution.name                                        description  \
# 7         Complete
# 8         Complete  Update to amqp-client 3.6.0 and spring-amqp 1.5.4
# 9         Complete  Related to XD-2567 which fixed this problem, b...
# 10        Complete                                       See INT-3956
# 11        Complete  The following XD components have been identifi...
#
#                                               summary
# 7                    Update Spring Framework to 4.2.4
# 8   Update Spring-AMQP to 3.6, RabbitMQ Client to ...
# 9     Suppress DeliveryMode Header in RabbitMQ Source
# 10  Update to Spring Integration 4.2.5 When Availa...
# 11  Enable in line SSL properties as an alternativ...

# %% [markdown]
# ## LDA

# %% [markdown]
# Import necessary things for LDA

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
np.random.seed(2018)
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Define preprocessing functions

# %%
# past and future tenses to present, third person to first person
def lemmatize_stemming(text):
    return SnowballStemmer("english").stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# remove stopwords and words that have 3 or less characters
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %% [markdown]
# Example of preprocessing

# %%
preprocess("This is an example of a preprocessed issue text")
# Out:
# ['exampl', 'preprocess', 'issu', 'text']

# %% [markdown]
# Preprocess all issue texts

# %%
processed_docs = df['text'].map(str).map(preprocess)
processed_docs.head()
# Out:
# 7                            [updat, spring, framework]
# 8     [updat, amqp, client, spring, amqp, updat, spr...
# 9     [relat, fix, problem, quot, releas, warn, supp...
# 10               [updat, spring, integr, avail, metric]
# 11    [follow, compon, identifi, support, sslpropert...
# 13    [maxwait, properti, server, messag, section, k...
# 14    [modul, allow, groovi, implement, filter, scri...
# 15    [spring, keep, password, text, file, server, p...
# 16    [follow, remov, https, github, spring, project...
# 17    [pubsub, consum, support, concurr, thread, com...
# Name: text, dtype: object

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %% [markdown]
# Train the LDA model

# %%
number_of_topics = 10
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=number_of_topics, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.034*"redi" + 0.031*"version" + 0.031*"spring" + 0.021*"data" + 0.016*"messag" + 0.014*"java" + 0.013*"like" + 0.013*"sink" + 0.013*"kafka" + 0.012*"connect"
# Topic: 1
# Words: 0.038*"spring" + 0.027*"java" + 0.025*"deploy" + 0.021*"stream" + 0.021*"hadoop" + 0.019*"modul" + 0.016*"springframework" + 0.015*"contain" + 0.014*"admin" + 0.013*"creat"
# Topic: 2
# Words: 0.032*"test" + 0.021*"modul" + 0.016*"messag" + 0.014*"current" + 0.013*"admin" + 0.013*"option" + 0.012*"batch" + 0.012*"start" + 0.011*"execut" + 0.011*"valu"
# Topic: 3
# Words: 0.151*"java" + 0.058*"springframework" + 0.036*"apach" + 0.020*"framework" + 0.018*"dirt" + 0.016*"curat" + 0.016*"stream" + 0.013*"util" + 0.013*"lang" + 0.012*"server"
# Topic: 4
# Words: 0.041*"creat" + 0.025*"test" + 0.024*"spring" + 0.022*"stream" + 0.020*"shell" + 0.017*"command" + 0.015*"file" + 0.012*"sink" + 0.011*"http" + 0.011*"hdfs"
# Topic: 5
# Words: 0.166*"java" + 0.109*"springframework" + 0.051*"integr" + 0.021*"core" + 0.016*"support" + 0.016*"channel" + 0.015*"invok" + 0.014*"util" + 0.013*"redi" + 0.013*"handler"
# Topic: 6
# Words: 0.068*"java" + 0.047*"spring" + 0.030*"dirt" + 0.028*"springframework" + 0.017*"test" + 0.015*"build" + 0.014*"project" + 0.013*"user" + 0.013*"warn" + 0.012*"main"
# Topic: 7
# Words: 0.069*"modul" + 0.027*"stream" + 0.024*"spring" + 0.022*"code" + 0.021*"java" + 0.019*"file" + 0.016*"springframework" + 0.016*"http" + 0.015*"sourc" + 0.013*"properti"
# Topic: 8
# Words: 0.051*"deploy" + 0.036*"modul" + 0.028*"stream" + 0.027*"contain" + 0.018*"spring" + 0.016*"job" + 0.016*"support" + 0.016*"need" + 0.013*"creat" + 0.010*"admin"
# Topic: 9
# Words: 0.065*"file" + 0.060*"java" + 0.044*"springframework" + 0.041*"modul" + 0.030*"user" + 0.028*"cach" + 0.026*"spring" + 0.025*"gradl" + 0.023*"bean" + 0.018*"factori"

# %% [markdown]
# Print the vector of the example issue

# %%
example_issue = df["text"].iloc[0]
print(example_issue)
bow_vector = dictionary.doc2bow(preprocess(example_issue))
for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
#  Update Spring Framework to 4.2.4
# Score: 0.5543716549873352	 Topic: 0.038*"spring" + 0.027*"java" + 0.025*"deploy" + 0.021*"stream" + 0.021*"hadoop"
# Score: 0.24557696282863617	 Topic: 0.151*"java" + 0.058*"springframework" + 0.036*"apach" + 0.020*"framework" + 0.018*"dirt"
# Score: 0.02500886656343937	 Topic: 0.068*"java" + 0.047*"spring" + 0.030*"dirt" + 0.028*"springframework" + 0.017*"test"
# Score: 0.0250079408288002	 Topic: 0.034*"redi" + 0.031*"version" + 0.031*"spring" + 0.021*"data" + 0.016*"messag"
# Score: 0.025007478892803192	 Topic: 0.041*"creat" + 0.025*"test" + 0.024*"spring" + 0.022*"stream" + 0.020*"shell"
# Score: 0.025006115436553955	 Topic: 0.065*"file" + 0.060*"java" + 0.044*"springframework" + 0.041*"modul" + 0.030*"user"
# Score: 0.025006111711263657	 Topic: 0.051*"deploy" + 0.036*"modul" + 0.028*"stream" + 0.027*"contain" + 0.018*"spring"
# Score: 0.025005504488945007	 Topic: 0.166*"java" + 0.109*"springframework" + 0.051*"integr" + 0.021*"core" + 0.016*"support"
# Score: 0.02500477246940136	 Topic: 0.032*"test" + 0.021*"modul" + 0.016*"messag" + 0.014*"current" + 0.013*"admin"
# Score: 0.025004591792821884	 Topic: 0.069*"modul" + 0.027*"stream" + 0.024*"spring" + 0.022*"code" + 0.021*"java"

# %% [markdown]
# ## Add topic vectors to backlog issues

# %%
def get_topic_vector(text, lda):
    bow_vector = dictionary.doc2bow(preprocess(text))
    topic_vector = lda[bow_vector]
    return [x for x in topic_vector]

# %%
get_topic_vector(example_issue, lda_model)
# Out:
# [(0, 0.025007945),
#  (1, 0.55415857),
#  (2, 0.025004774),
#  (3, 0.24579003),
#  (4, 0.025007484),
#  (5, 0.025005497),
#  (6, 0.025008865),
#  (7, 0.025004594),
#  (8, 0.025006117),
#  (9, 0.025006115)]

# %% [markdown]
# Add topic vector to all backlog issues

# %%
backlog["vector"]= backlog.apply(lambda x: get_topic_vector(x["text"], lda_model), axis=1)
backlog.head()
# Out:
# <ipython-input-208-57d27f698719>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   backlog["vector"]= backlog.apply(lambda x: get_topic_vector(x["text"], lda_model), axis=1)
#                         created assignee.name  priority status.name  \
# 0  2016-03-31T22:35:55.000+0000           NaN         2       To Do
# 1  2016-03-14T18:09:51.000+0000           NaN         1       To Do
# 3  2016-02-29T10:00:18.000+0000           NaN         3       To Do
# 4  2016-02-26T15:57:18.000+0000           NaN         3       To Do
# 6  2016-02-23T18:31:37.000+0000           NaN         2       To Do
#
#                                                 text  storypoints project  \
# 0  The MapReduce samples should have "yarn.resour...          2.0      xd
# 1  When i use the admin-ui web portal which runs ...         20.0      xd
# 3  if we put a custom module static properties in...          1.0      xd
# 4  Custom conversion is broken.\r\r\n\r\r\nIf the...          5.0      xd
# 6  http://stackoverflow.com/questions/35563064/pr...          1.0      xd
#
#   resolution.name                                        description  \
# 0             NaN  The MapReduce samples should have "yarn.resour...
# 1             NaN  When i use the admin-ui web portal which runs ...
# 3             NaN  if we put a custom module static properties in...
# 4             NaN  Custom conversion is broken.\r\r\n\r\r\nIf the...
# 6             NaN  http://stackoverflow.com/questions/35563064/pr...
#
#                                              summary  \
# 0  Add "yarn.resourcemanager.scheduler.address" t...
# 1  Admin UI login Page failing to load due to req...
# 3  Cant completely remove custom module after put...
# 4  Provisioning of Custom input/output Converters...
# 6  Rabbit Bus: Expose ChannelCacheSize on Caching...
#
#                                               vector
# 0  [(1, 0.25293422), (4, 0.18379036), (8, 0.50492...
# 1                                   [(2, 0.9526176)]
# 3  [(4, 0.28898335), (7, 0.40477943), (8, 0.29277...
# 4                                  [(7, 0.97630906)]
# 6  [(0, 0.012503843), (1, 0.012502699), (2, 0.012...

# %% [markdown]
# ## Add "experience" topic vectors to users

# %% [markdown]
# Concatenate all issue texts for users

# %%
user_df = df.groupby("assignee.name").agg({'text': 'sum'})
user_df["text"].iloc[0]
# Out:
# "See INT-3956 Update to Spring Integration 4.2.5 When Available (Fix Metrics)As a user, I'd like to have the option of _Cassandra_ sink, so I can leverage the NoSQL database to write high volumes of variable data segments in high velocity. Add Cassandra sink"

# %%
user_df["vector"] = user_df["text"].apply(get_topic_vector, args=(lda_model,))
user_df.head()
# Out:
#                                                             text  \
# assignee.name
# abilan         See INT-3956 Update to Spring Integration 4.2....
# aclement       As a developer, I'd like to enhance test cover...
# aeisenberg     We should consider moving to wire.js to encour...
# chrisschaefer  Based on the the results from B-6, select the ...
# david_syer      Use Boot plugin and IO Platform for versions ...
#
#                                                           vector
# assignee.name
# abilan                                          [(0, 0.9437351)]
# aclement                                        [(7, 0.9888994)]
# aeisenberg     [(2, 0.40002513), (4, 0.14699723), (6, 0.15146...
# chrisschaefer                 [(0, 0.70138997), (2, 0.29490596)]
# david_syer     [(2, 0.31258088), (4, 0.24474378), (6, 0.10234...

# %%
from scipy import spatial

spatial.distance.cosine([0,1], [2,2])
# Out:
# 0.29289321881345254

# %%
def topic_to_vector(topic, number_of_topics):
    vector = np.zeros(number_of_topics)
    for x in topic:
        vector[x[0]] = [x[1]]
    return vector
